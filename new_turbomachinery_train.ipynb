# %%
import gc
import numpy
import pandas
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %%
train_data = pandas.read_csv('train_data.csv', index_col='Timestamp')

# %%
train_data.plot(subplots=True, figsize=(13, 37))
# Out:
# array([<AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
#        <AxesSubplot: xlabel='Timestamp'>,
# ...
