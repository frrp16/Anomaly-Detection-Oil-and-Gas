# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear TS

# %%
linear = pd.read_csv('../../Documents/phd_related/ing/data_monitoring/synthetic_datasets_time_series/lin-1.csv', header = None)
linear
# Out:
#            0
# 0     -0.795
# 1     -0.700
# 2     -0.523
# 3     -0.333
# 4     -0.482
# ...      ...
# 19995  0.104
# 19996  0.025
# 19997 -0.155
# 19998 -0.012
# 19999  0.010
#
# [20000 rows x 1 columns]

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['figure.figsize'] = (25,6)

plt.plot(linear)
plt.title('Linear Time Series')
plt.xlabel('Timestamp')
plt.ylabel('Value')
for i in range(0, 20001, 2000):
    if(i == 0 or i == 20000):
        plt.axvline(x = i, color = 'b')
    else:
        plt.axvline(x = i, color = 'r')
plt.axvspan(12000, 14000, facecolor = 'y', alpha = 0.2)

# %% [markdown]
# # Non-Linear TS

# %%
nonlinear = pd.read_csv('../../Documents/phd_related/ing/data_monitoring/synthetic_datasets_time_series/nlin-1.csv', header = None)
nonlinear
# Out:
#            0
# 0      0.064
# 1      0.033
# 2      0.363
# 3     -0.038
# 4      0.367
# ...      ...
# 19995  0.142
# 19996 -0.019
# 19997 -0.062
# 19998  0.211
# 19999  0.002
#
# [20000 rows x 1 columns]

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['figure.figsize'] = (25,6)

plt.plot(nonlinear)
plt.title('Non-Linear Time Series')
plt.xlabel('Timestamp')
plt.ylabel('Value')
for i in range(0, 20001, 2000):
    if(i == 0 or i == 20000):
        plt.axvline(x = i, color = 'b')
    else:
        plt.axvline(x = i, color = 'r')
plt.axvspan(12000, 14000, facecolor = 'y', alpha = 0.2)

# %% [markdown]
# # Seasonal TS

# %%
seasonal = pd.read_csv('../../Documents/phd_related/ing/data_monitoring/synthetic_datasets_time_series/saz-1.csv', header = None)
seasonal
# Out:
#             0
# 0      33.394
# 1      34.117
# 2      33.957
# 3      24.850
# 4      30.741
# ...       ...
# 19995  14.269
# 19996  23.472
# 19997  27.773
# 19998  33.154
# 19999  21.076
#
# [20000 rows x 1 columns]

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['figure.figsize'] = (25,6)

plt.plot(seasonal)
plt.title('Seasonal Time Series')
plt.xlabel('Timestamp')
plt.ylabel('Value')
for i in range(0, 20001, 2000):
    if(i == 0 or i == 20000):
        plt.axvline(x = i, color = 'b')
    else:
        plt.axvline(x = i, color = 'r')
plt.axvspan(12000, 14000, facecolor = 'y', alpha = 0.2)

# %% [markdown]
# # Hybrid TS

# %%
hybrid = pd.read_csv('../../Documents/phd_related/ing/data_monitoring/synthetic_datasets_time_series/hib-1.csv', header = None)
hybrid
# Out:
#            0
# 0      1.270
# 1      1.251
# 2      1.067
# 3      1.050
# 4      1.098
# ...      ...
# 19995  0.579
# 19996  1.010
# 19997  0.547
# 19998  0.966
# 19999  0.557
#
# [20000 rows x 1 columns]

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['figure.figsize'] = (25,6)
plt.rc('legend',fontsize=16) 

plt.plot(hybrid)
plt.title('Hybrid Time Series')
plt.xlabel('Timestamp')
plt.ylabel('Value')
for i in range(0, 20001, 2000):
    if(i == 0 or i == 20000):
        plt.axvline(x = i, color = 'b')
    else:
        plt.axvline(x = i, color = 'r')

label = 'Linear'
for i in range(0, 20001, 6000):
    plt.axvspan(i, i+2000, facecolor = 'y', alpha = 0.2, label = label)
    label = "_nolegend_"

label = 'Seasonal'
for i in range(2000, 18001, 6000):
    plt.axvspan(i, i+2000, facecolor = 'g', alpha = 0.2, label = label)
    label = "_nolegend_"

label = 'Non-Linear'
for i in range(4000, 16001, 6000):
    plt.axvspan(i, i+2000, facecolor = 'pink', alpha = 0.2, label = label)
    label = "_nolegend_"

plt.legend()
