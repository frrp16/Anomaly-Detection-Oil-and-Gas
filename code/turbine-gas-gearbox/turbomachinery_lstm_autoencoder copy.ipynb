# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import pickle
# Out:
# 2024-10-13 16:38:15.955409: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-13 16:38:16.092325: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-13 16:38:16.092416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-13 16:38:16.099713: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-13 16:38:16.108018: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-13 16:38:17.164726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-10-13 16:38:18.340037: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 16:38:18.390716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 16:38:18.390760: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu,
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])  # Set your memory limit here
    except RuntimeError as e:
        print(e)

# %%
def inverse_convert_time_window(data_3d):
    samples, timesteps, variables = data_3d.shape
    data_2d = np.zeros((samples + timesteps - 1, variables))

    count = np.zeros((samples + timesteps - 1, variables))

    for i in range(samples):
        data_2d[i:i+timesteps] += data_3d[i]
        count[i:i+timesteps] += 1

    # Average the overlapping segments
    data_2d /= count
    return data_2d

# %%
def convert_time_window(data, timesteps):
    samples = data.shape[0] - timesteps + 1  # Number of samples in the new 3D array
    variables = data.shape[1]  # Number of variables (features)

    data_3d = np.zeros((samples, timesteps, variables))

    for i in range(samples):
        data_3d[i] = data[i:i+timesteps]
    return data_3d

# %%
def calculate_reconstruction_loss(data, reconstructions):
    reconstruction_errors = np.mean(np.abs(data - reconstructions), axis=1)
    total_r_e = np.sum(reconstruction_errors)
    relative_reconstruction_errors = np.array([(r_e / total_r_e) * 100 for r_e in reconstruction_errors])
    return reconstruction_errors

# %%
def find_optimal_threshold(reconstruction_errors, y_true):
    from sklearn.metrics import accuracy_score, balanced_accuracy_score

    best_threshold = 0.0
    best_f1 = 0.0
    best_y_pred = np.zeros(reconstruction_errors.shape)
    # q3 = np.percentile(reconstruction_errors, 75)
    # q1 = np.percentile(reconstruction_errors, 25)
    # iqr = q3 - q1
    upper_bound = np.max(reconstruction_errors)
    lower_bound = np.min(reconstruction_errors)

    thresholds = np.linspace(lower_bound, upper_bound, num=1000)

    for threshold in thresholds:
        y_pred = np.where((reconstruction_errors > threshold) ,1, 0)
        # print(y_pred.shape)
        # print(y_true.shape)

        # Hitung F1-Score
        current_f1 = balanced_accuracy_score(y_true.astype(bool), y_pred.astype(bool))

        if current_f1 > best_f1:
            best_f1 = current_f1
            best_threshold = threshold
            best_y_pred = y_pred

    return best_threshold, best_f1, best_y_pred

# def find_optimal_threshold(reconstruction_errors, y_true):
#     from sklearn.metrics import f1_score, accuracy_score
    
#     best_threshold = 0.0
#     best_f1 = 0.0
#     best_y_pred = np.zeros(reconstruction_errors.shape)
#     q3 = np.percentile(reconstruction_errors, 75)
#     q1 = np.percentile(reconstruction_errors, 25)
#     iqr = q3 - q1
#     upper_bound = max(np.max(reconstruction_errors) / 2, (q3 + iqr * 1.5))
#     lower_bound = min(np.min(reconstruction_errors) / 2, (q1 - iqr * 1.5))

#     thresholds = np.linspace(lower_bound, upper_bound, num=500)

#     for threshold in thresholds:
#         y_pred = np.where(
#             (reconstruction_errors > (threshold + iqr)) | 
#             (reconstruction_errors < (threshold - iqr)),
#               1, 0)
#         # print(y_pred.shape)
#         # print(y_true.shape)

#         current_f1 = accuracy_score(y_true.astype(bool), y_pred.astype(bool))

#         if current_f1 > best_f1:
#             best_f1 = current_f1
#             best_threshold = threshold
#             best_y_pred = y_pred

#     return best_threshold, best_f1, best_y_pred

# %% [markdown]
# ## ================================================================

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pickle

df = pd.read_csv("../../datasets/turbine-gas-gearbox/BLD-LGC PTGBX 26 JUL21-8FEB23_edited.csv", index_col='Timestamp')

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
pickle.dump(scaler, open('StandardScaler-gearbox.pkl', 'wb'))

# %%
# pd.DataFrame(df_scaled, columns=df.columns).plot(figsize=(20,8))
df.index = pd.to_datetime(df.index, format='mixed')
plt.figure(figsize=(20,13))
plt.plot(df.index, df_scaled, label=df.columns)
plt.legend()
plt.show()
# Out:
# /home/farras/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.shape
# if 'Gear LS Inboard Thrust Brg Temp' in df.columns:
#     df.drop('Gear LS Inboard Thrust Brg Temp', axis=1, inplace=True)
# Out:
# (161788, 31)

# %%
df_sample = df.reset_index().loc[:60000-1]
df_sample.to_csv("../../datasets/turbine-gas-gearbox/data_sample.csv", index=False)

# %%
df_sample_test = df.reset_index().loc[60000:70000-1]
df_sample_test.to_csv("../../datasets/turbine-gas-gearbox/data_sample_test.csv", index=False)

# %% [markdown]
# ## ==========================================

# %%
df_sample = pd.read_csv("../../datasets/turbine-gas-gearbox/data_sample.csv", index_col="Timestamp")
print(df_sample.shape)
# Out:
# (60000, 31)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pickle

# scaler = MinMaxScaler([0,1])
scaler = pickle.load(open('StandardScaler-gearbox.pkl', 'rb'))
df_sample_scaled = scaler.transform(df_sample)

# %%
plt.figure(figsize=(20,14))
plt.plot(df_sample_scaled)
plt.plot(np.full(df_sample_scaled.shape[0], -3))
plt.plot(np.full(df_sample_scaled.shape[0], 3))
plt.legend(df_sample.columns)
plt.plot()
# Out:
# []

# %%
df_sample['label'] = np.where(np.any((df_sample_scaled < -3) | (df_sample_scaled > 3), axis=1), 1, 0)

# %%
# from sklearn.neighbors import LocalOutlierFactor
# lof = LocalOutlierFactor()

# yyy = lof.fit_predict(df_sample_scaled)

# %%
plt.figure(figsize=(20,14))
plt.plot(df_sample_scaled)
xmin, xmax, ymin, ymax = plt.axis()
plt.fill_between(np.arange(0, df_sample_scaled.shape[0]), ymin, ymax, where=(df_sample['label'] == 0), color='green', alpha=0.3)
plt.fill_between(np.arange(0, df_sample_scaled.shape[0]), ymin, ymax, where=(df_sample['label'] == 1), color='red', alpha=0.3)
plt.legend(df_sample.columns)
plt.plot()
# Out:
# []

# %%
df_sample.loc[df_sample['label'] == 0,:].shape
# Out:
# (57449, 32)

# %%
df_sample_scaled = scaler.transform(df_sample.loc[df_sample['label'] == 0,:].drop("label", axis=1))

# %%
plt.figure(figsize=(20,14))
plt.plot(df_sample_scaled)
plt.legend(df_sample.columns)
plt.plot()
# Out:
# []

# %%
df_sample_scaled_3d = convert_time_window(df_sample_scaled, 20)

# %%
def create_lstm_autoencoder(timesteps, n_features):
    # Encoder
    input_layer = keras.layers.Input(shape=(timesteps, n_features))
    encoder = keras.layers.LSTM(128, return_sequences=True)(input_layer)
    encoder = keras.layers.LSTM(64, return_sequences=True)(encoder)
    encoder = keras.layers.LSTM(32)(encoder)
    encoder = keras.layers.Dense(24, activation='relu')(encoder)
    encoded_output = keras.layers.Dense(10, activation='relu')(encoder)

    # Decoder
    decoder = keras.layers.Dense(10, activation='relu')(encoded_output)
    decoder = keras.layers.Dense(24, activation='relu')(decoder)
    decoder = keras.layers.RepeatVector(timesteps)(decoder)

    decoder = keras.layers.LSTM(32, return_sequences=True)(decoder)
    decoder = keras.layers.LSTM(64, return_sequences=True)(decoder)
    decoder = keras.layers.LSTM(128, return_sequences=True)(decoder)

    decoded_output = keras.layers.TimeDistributed(keras.layers.Dense(n_features))(decoder)

    # Define the full autoencoder model
    autoencoder = keras.models.Model(inputs=input_layer, outputs=decoded_output, name="Autoencoder")

    return autoencoder

# %%
with tf.device('/GPU:0'):
    lstm_model = create_lstm_autoencoder(20, df_sample_scaled.shape[1])
lstm_model.summary()
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 20, 31)]          0
#
#  lstm_12 (LSTM)              (None, 20, 128)           81920
#
#  lstm_13 (LSTM)              (None, 20, 64)            49408
#
#  lstm_14 (LSTM)              (None, 32)                12416
#
#  dense_10 (Dense)            (None, 24)                792
#
#  dense_11 (Dense)            (None, 10)                250
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 24)                264
#
#  repeat_vector_2 (RepeatVec  (None, 20, 24)            0
#  tor)
#
#  lstm_15 (LSTM)              (None, 20, 32)            7296
#
#  lstm_16 (LSTM)              (None, 20, 64)            24832
#
#  lstm_17 (LSTM)              (None, 20, 128)           98816
#
#  time_distributed_2 (TimeDi  (None, 20, 31)            3999
#  stributed)
#
# =================================================================
# Total params: 280103 (1.07 MB)
# Trainable params: 280103 (1.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def myCallbacks(log_dir):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='loss',
    patience=10,
    mode='min')
    model_path = os.path.join(log_dir,'best_model.h5')
    mc = tf.keras.callbacks.ModelCheckpoint(model_path, monitor='loss', mode='min', verbose=1, save_best_only=False)
    return [tensorboard_callback, early_stopping, mc]

# %%
lstm_model.compile(loss='mse', optimizer=keras.optimizers.Adam(), metrics=['acc'])

# %%
with tf.device('/GPU:0'):
    history = lstm_model.fit(df_sample_scaled_3d, df_sample_scaled_3d, callbacks=myCallbacks('../logs/train-new-20/1'), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0162 - acc: 0.8038
# Epoch 1: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 30ms/step - loss: 0.0162 - acc: 0.8038
# Epoch 2/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.8577
# Epoch 2: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0092 - acc: 0.8577
# Epoch 3/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0066 - acc: 0.8787
# Epoch 3: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0066 - acc: 0.8787
# Epoch 4/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0057 - acc: 0.8867
# Epoch 4: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0057 - acc: 0.8867
# Epoch 5/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0054 - acc: 0.8886
# Epoch 5: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 57s 32ms/step - loss: 0.0054 - acc: 0.8886
# Epoch 6/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.8897
# Epoch 6: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0051 - acc: 0.8897
# Epoch 7/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.8920
# Epoch 7: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0049 - acc: 0.8920
# Epoch 8/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.8922
# Epoch 8: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0048 - acc: 0.8922
# Epoch 9/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.8923
# Epoch 9: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 67s 37ms/step - loss: 0.0049 - acc: 0.8923
# Epoch 10/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.8960
# Epoch 10: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 66s 37ms/step - loss: 0.0046 - acc: 0.8960
# Epoch 11/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0045 - acc: 0.8966
# Epoch 11: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 60s 33ms/step - loss: 0.0045 - acc: 0.8966
# Epoch 12/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0044 - acc: 0.8980
# Epoch 12: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 67s 38ms/step - loss: 0.0044 - acc: 0.8980
# Epoch 13/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.8990
# Epoch 13: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 69s 38ms/step - loss: 0.0043 - acc: 0.8990
# Epoch 14/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0042 - acc: 0.8997
# Epoch 14: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0042 - acc: 0.8997
# Epoch 15/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0042 - acc: 0.9005
# Epoch 15: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0042 - acc: 0.9005
# Epoch 16/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0041 - acc: 0.9027
# Epoch 16: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 57s 32ms/step - loss: 0.0041 - acc: 0.9027
# Epoch 17/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.8995
# Epoch 17: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0045 - acc: 0.8995
# Epoch 18/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0040 - acc: 0.9045
# Epoch 18: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 65s 36ms/step - loss: 0.0040 - acc: 0.9045
# Epoch 19/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.9048
# Epoch 19: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 83s 46ms/step - loss: 0.0040 - acc: 0.9048
# Epoch 20/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.9065
# Epoch 20: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0038 - acc: 0.9065
# Epoch 21/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9053
# Epoch 21: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 33ms/step - loss: 0.0039 - acc: 0.9053
# Epoch 22/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.8944
# Epoch 22: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0045 - acc: 0.8944
# Epoch 23/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9065
# Epoch 23: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0038 - acc: 0.9065
# Epoch 24/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.9072
# Epoch 24: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0037 - acc: 0.9072
# Epoch 25/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9087
# Epoch 25: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 29ms/step - loss: 0.0035 - acc: 0.9087
# Epoch 26/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0035 - acc: 0.9103
# Epoch 26: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0035 - acc: 0.9103
# Epoch 27/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0035 - acc: 0.9092
# Epoch 27: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0035 - acc: 0.9092
# Epoch 28/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9043
# Epoch 28: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0038 - acc: 0.9043
# Epoch 29/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9016
# Epoch 29: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0039 - acc: 0.9016
# Epoch 30/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.9103
# Epoch 30: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0034 - acc: 0.9103
# Epoch 31/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9111
# Epoch 31: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0033 - acc: 0.9111
# Epoch 32/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9112
# Epoch 32: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0033 - acc: 0.9113
# Epoch 33/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0033 - acc: 0.9124
# Epoch 33: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0033 - acc: 0.9124
# Epoch 34/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9122
# Epoch 34: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0033 - acc: 0.9122
# Epoch 35/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9123
# Epoch 35: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0033 - acc: 0.9123
# Epoch 36/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.9131
# Epoch 36: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0032 - acc: 0.9131
# Epoch 37/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.9134
# Epoch 37: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0032 - acc: 0.9134
# Epoch 38/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9123
# Epoch 38: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0033 - acc: 0.9123
# Epoch 39/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0033 - acc: 0.9120
# Epoch 39: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0033 - acc: 0.9120
# Epoch 40/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.9143
# Epoch 40: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0032 - acc: 0.9143
# Epoch 41/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9137
# Epoch 41: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0032 - acc: 0.9137
# Epoch 42/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9147
# Epoch 42: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 68s 38ms/step - loss: 0.0031 - acc: 0.9147
# Epoch 43/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9140
# Epoch 43: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 62s 34ms/step - loss: 0.0032 - acc: 0.9140
# Epoch 44/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9151
# Epoch 44: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 62s 35ms/step - loss: 0.0031 - acc: 0.9151
# Epoch 45/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9148
# Epoch 45: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0031 - acc: 0.9148
# Epoch 46/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9156
# Epoch 46: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0030 - acc: 0.9156
# Epoch 47/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9138
# Epoch 47: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 65s 36ms/step - loss: 0.0032 - acc: 0.9138
# Epoch 48/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9128
# Epoch 48: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 62s 34ms/step - loss: 0.0032 - acc: 0.9128
# Epoch 49/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9165
# Epoch 49: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9165
# Epoch 50/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9151
# Epoch 50: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9151
# Epoch 51/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9163
# Epoch 51: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9163
# Epoch 52/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9155
# Epoch 52: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0031 - acc: 0.9155
# Epoch 53/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9163
# Epoch 53: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9163
# Epoch 54/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9161
# Epoch 54: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 61s 34ms/step - loss: 0.0030 - acc: 0.9161
# Epoch 55/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9132
# Epoch 55: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 57s 32ms/step - loss: 0.0033 - acc: 0.9132
# Epoch 56/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9167
# Epoch 56: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9167
# Epoch 57/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9169
# Epoch 57: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0030 - acc: 0.9169
# Epoch 58/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9174
# Epoch 58: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0029 - acc: 0.9174
# Epoch 59/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9179
# Epoch 59: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 60s 33ms/step - loss: 0.0029 - acc: 0.9179
# Epoch 60/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9150
# Epoch 60: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0030 - acc: 0.9150
# Epoch 61/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9165
# Epoch 61: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 33ms/step - loss: 0.0029 - acc: 0.9165
# Epoch 62/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9178
# Epoch 62: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0029 - acc: 0.9178
# Epoch 63/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9181
# Epoch 63: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0029 - acc: 0.9181
# Epoch 64/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.9138
# Epoch 64: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0032 - acc: 0.9139
# Epoch 65/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9180
# Epoch 65: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0028 - acc: 0.9180
# Epoch 66/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9185
# Epoch 66: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 57s 32ms/step - loss: 0.0028 - acc: 0.9185
# Epoch 67/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9152
# Epoch 67: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 57s 32ms/step - loss: 0.0030 - acc: 0.9152
# Epoch 68/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9175
# Epoch 68: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0029 - acc: 0.9176
# Epoch 69/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9188
# Epoch 69: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9188
# Epoch 70/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9149
# Epoch 70: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0029 - acc: 0.9149
# Epoch 71/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9162
# Epoch 71: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0029 - acc: 0.9162
# Epoch 72/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9184
# Epoch 72: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9184
# Epoch 73/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9191
# Epoch 73: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9191
# Epoch 74/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9188
# Epoch 74: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9188
# Epoch 75/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9189
# Epoch 75: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9189
# Epoch 76/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9191
# Epoch 76: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0028 - acc: 0.9191
# Epoch 77/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9191
# Epoch 77: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0028 - acc: 0.9191
# Epoch 78/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9194
# Epoch 78: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0028 - acc: 0.9194
# Epoch 79/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9194
# Epoch 79: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9194
# Epoch 80/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0027 - acc: 0.9199
# Epoch 80: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0027 - acc: 0.9199
# Epoch 81/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9187
# Epoch 81: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9187
# Epoch 82/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.9184
# Epoch 82: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0029 - acc: 0.9184
# Epoch 83/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9204
# Epoch 83: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 29ms/step - loss: 0.0027 - acc: 0.9204
# Epoch 84/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9191
# Epoch 84: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0028 - acc: 0.9191
# Epoch 85/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0027 - acc: 0.9208
# Epoch 85: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0027 - acc: 0.9208
# Epoch 86/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.9196
# Epoch 86: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 54s 30ms/step - loss: 0.0028 - acc: 0.9196
# Epoch 87/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9210
# Epoch 87: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0027 - acc: 0.9211
# Epoch 88/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9197
# Epoch 88: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0028 - acc: 0.9197
# Epoch 89/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0027 - acc: 0.9205
# Epoch 89: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 52s 29ms/step - loss: 0.0027 - acc: 0.9205
# Epoch 90/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9211
# Epoch 90: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0027 - acc: 0.9211
# Epoch 91/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9209
# Epoch 91: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 31ms/step - loss: 0.0027 - acc: 0.9209
# Epoch 92/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9216
# Epoch 92: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0026 - acc: 0.9216
# Epoch 93/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9208
# Epoch 93: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0027 - acc: 0.9208
# Epoch 94/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0027 - acc: 0.9207
# Epoch 94: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0027 - acc: 0.9207
# Epoch 95/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9213
# Epoch 95: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 58s 32ms/step - loss: 0.0026 - acc: 0.9213
# Epoch 96/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9212
# Epoch 96: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 59s 33ms/step - loss: 0.0027 - acc: 0.9212
# Epoch 97/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9217
# Epoch 97: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 56s 31ms/step - loss: 0.0026 - acc: 0.9217
# Epoch 98/100
# 1795/1795 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9214
# Epoch 98: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 60s 33ms/step - loss: 0.0026 - acc: 0.9214
# Epoch 99/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.9217
# Epoch 99: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 53s 30ms/step - loss: 0.0026 - acc: 0.9217
# Epoch 100/100
# 1794/1795 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9210
# Epoch 100: saving model to ../logs/train-new-20/1/best_model.h5
# 1795/1795 [==============================] - 55s 30ms/step - loss: 0.0027 - acc: 0.9210

# %% [markdown]
# ## ============================================

# %%
lstm_model = keras.models.load_model("../logs/train-new-20/1/best_model.h5")
train_3d_np = lstm_model.predict(df_sample_scaled_3d)
train_2d_np = inverse_convert_time_window(train_3d_np)
# Out:
# 2024-10-11 16:31:36.794344: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:36.794534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:36.794568: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:38.178092: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:38.178119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-10-11 16:31:38.178151: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:38.178175: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 16:31:38.178194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4096 MB memory:  -> device: 0, name: NVIDIA T500, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2024-10-11 16:31:38.887345: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-10-11 16:31:41.984522: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 1795/1795 [==============================] - 18s 9ms/step

# %%
r_e = calculate_reconstruction_loss(df_sample_scaled, train_2d_np)

# %%
plt.figure(figsize=(13,7))
# plt.plot(df_sample_scaled)
plt.plot(train_2d_np)
plt.show()

# %%
print("Max: ", np.max(r_e))
print("Min: ", np.min(r_e))
print("Avg: ", np.mean(r_e))
print("Median: ", np.median(r_e))
print("75%: ", np.percentile(r_e, 75))
print("25%: ", np.percentile(r_e, 25))
print("IQR: ", np.percentile(r_e, 75) - np.percentile(r_e, 25))
# Out:
# Max:  0.5540437327270114
# Min:  0.003704381807184186
# Avg:  0.03259095820525266
# Median:  0.0315322604790579
# 75%:  0.0367884325488601
# 25%:  0.02720557753730194
# IQR:  0.009582855011558158

# %%
plt.figure(figsize=(13,7))
plt.plot(r_e)
# plt.plot(np.full(r_e.shape[0], thres))
# xmin, xmax, ymin, ymax = plt.axis()
# plt.fill_betweenx(np.arange(thres-iqr, thres+iqr), r_e.shape[0], color='gray', alpha=0.3)
plt.title("Reconstruction error")
plt.show()

# %%
pd.DataFrame(r_e).to_csv("../../reconstruction_error/gearbox/reconstruction_error-20t.csv", index=False)

# %% [markdown]
# ## ===============================================

# %%
df_sample_test = pd.read_csv("../../datasets/turbine-gas-gearbox/data_sample_test.csv", index_col="Timestamp")
scaler_test = pickle.load(open('StandardScaler-gearbox.pkl', 'rb'))
df_sample_test_scaled = scaler_test.transform(df_sample_test)

# %%
df_sample_test_label = np.where(np.any((df_sample_test_scaled < -3) | (df_sample_test_scaled > 3), axis=1), 1, 0)

# %%
plt.figure(figsize=(20,13))
plt.plot(df_sample_test_scaled)
xmin, xmax, ymin, ymax = plt.axis()
plt.fill_between(np.arange(0, df_sample_test_scaled.shape[0]), ymin, ymax, where=(df_sample_test_label == 0), color='green', alpha=0.3)
plt.fill_between(np.arange(0, df_sample_test_scaled.shape[0]), ymin, ymax, where=(df_sample_test_label == 1), color='red', alpha=0.3)
plt.legend(df_sample_test.columns)
plt.show()

# %%
df_sample_test_scaled_3d = convert_time_window(df_sample_test_scaled, 20)

# %%
model = keras.models.load_model("../logs/train-new-20/1/best_model.h5")
model.summary()
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 20, 31)]          0
#
#  lstm_12 (LSTM)              (None, 20, 128)           81920
#
#  lstm_13 (LSTM)              (None, 20, 64)            49408
#
#  lstm_14 (LSTM)              (None, 32)                12416
#
#  dense_10 (Dense)            (None, 24)                792
#
#  dense_11 (Dense)            (None, 10)                250
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 24)                264
#
#  repeat_vector_2 (RepeatVec  (None, 20, 24)            0
#  tor)
#
#  lstm_15 (LSTM)              (None, 20, 32)            7296
#
#  lstm_16 (LSTM)              (None, 20, 64)            24832
#
#  lstm_17 (LSTM)              (None, 20, 128)           98816
#
#  time_distributed_2 (TimeDi  (None, 20, 31)            3999
#  stributed)
#
# =================================================================
# Total params: 280103 (1.07 MB)
# Trainable params: 280103 (1.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pred = model.predict(df_sample_test_scaled_3d)
# Out:
# 312/312 [==============================] - 4s 9ms/step

# %%
pred_2d_inv = inverse_convert_time_window(pred)
# r_e = calculate_reconstruction_loss(df_sample_test_scaled, pred_2d_inv)

# %%
plt.figure(figsize=(13,7))
plt.plot(df_sample_test_scaled)
plt.plot(pred_2d_inv)
plt.show()

# %%
r_e = calculate_reconstruction_loss(df_sample_test_scaled, pred_2d_inv)
# thres = 0.5831722671849883
# thres = 0.03036027381691517
thres = 0.034154447668272886 + (1.5 * 0.008287947844526241)

# %%
thres, f1, y_pred = find_optimal_threshold((r_e), np.array(df_sample_test_label))
print(thres, f1)
# Out:
# 0.27871435791953303 0.9972950523190065

# %%
# iqr = np.percentile(r_e, 75) - np.percentile(r_e, 25)

plt.figure(figsize=(13,7))
plt.plot(r_e)
plt.plot(np.full(r_e.shape[0], thres))
xmin, xmax, ymin, ymax = plt.axis()
# plt.fill_betweenx(np.arange(thres-iqr, thres+iqr), r_e.shape[0], color='gray', alpha=0.3)
plt.title("Reconstruction error")
plt.show()

# %%
plt.figure(figsize=(20,13))
plt.plot(df_sample_test_scaled)
xmin, xmax, ymin, ymax = plt.axis()
plt.fill_between(np.arange(0, df_sample_test_scaled.shape[0]), ymin, ymax, where=(df_sample_test_label == 0), color='green', alpha=0.3)
plt.fill_between(np.arange(0, df_sample_test_scaled.shape[0]), ymin, ymax, where=(df_sample_test_label == 1), color='red', alpha=0.3)
plt.fill_between(np.arange(0,df_sample_test_scaled.shape[0]), ymin, ymax,where=(~df_sample_test_label.astype(bool) & y_pred ), color='yellow', alpha=0.3)
plt.legend(df_sample_test.columns)
plt.show()

# %%
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(np.array(df_sample_test_label).astype(bool), y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'anomaly'])
cm_display.plot()
