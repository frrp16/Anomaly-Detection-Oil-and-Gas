# %%
import os
import sys
import time
import shutil
import pickle

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.metrics import f1_score
from tensorflow import keras
from tensorflow.keras import layers, models

import sklearn.preprocessing
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
# Out:
# 2024-10-13 18:07:56.793475: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-13 18:07:56.832892: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-13 18:07:56.832930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-13 18:07:56.834053: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-13 18:07:56.842809: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-13 18:07:57.757013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.15.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-10-13 18:07:59.021840: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:07:59.067137: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:07:59.067185: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
def get_dataset(directory, single_file=False, use_half=False, section=1, use_num_files=False, num_files=100):  
    if single_file:
        df = pd.read_csv(directory, index_col='timestamp')
        df.dropna(inplace=True)
        return df
    
    merged_df = pd.DataFrame()
    list_files = os.listdir(directory)
    print(len(list_files))
    if use_num_files:
        for i in range(num_files):
            df = pd.read_csv(os.path.join(directory, list_files[i]), index_col='timestamp')
            df.dropna(inplace=True)
            merged_df = pd.concat([merged_df, df], ignore_index=True)

    if use_half:
        for i, files in enumerate(list_files):
            if section==1:
                if i > len(list_files) //2:
                    continue
                df = pd.read_csv(os.path.join(directory, files), index_col='timestamp')
                df.dropna(inplace=True)
                merged_df = pd.concat([merged_df, df], ignore_index=True)
            if section==2:
                if i <= len(list_files) // 2:
                    continue
                df = pd.read_csv(os.path.join(directory, files), index_col='timestamp')
                df.dropna(inplace=True)
                merged_df = pd.concat([merged_df, df], ignore_index=True)
    else:
        for files in list_files:
            df = pd.read_csv(os.path.join(directory, files), index_col='timestamp')
            df.dropna(inplace=True)
            merged_df = pd.concat([merged_df, df], ignore_index=True)
    
    # print(i)
    return merged_df

# %%
def convert_time_window(data, timesteps):
    samples = data.shape[0] - timesteps + 1  # Number of samples in the new 3D array
    variables = data.shape[1]  # Number of variables (features)

    data_3d = np.zeros((samples, timesteps, variables), dtype='float32')

    for i in range(samples):
        data_3d[i] = data[i:i+timesteps]
    return data_3d

# %%
def inverse_convert_time_window(data_3d):
    samples, timesteps, variables = data_3d.shape
    data_2d = np.zeros((samples + timesteps - 1, variables))

    count = np.zeros((samples + timesteps - 1, variables))

    for i in range(samples):
        data_2d[i:i+timesteps] += data_3d[i]
        count[i:i+timesteps] += 1

    # Average the overlapping segments
    data_2d /= count
    return data_2d

# %%
def calculate_reconstruction_loss(data, reconstructions):
    reconstruction_errors = np.mean(np.abs(data - reconstructions), axis=1)
    total_r_e = np.sum(reconstruction_errors)
    max_r_e = np.max(reconstruction_errors)
    relative_reconstruction_errors = np.array([(r_e / total_r_e) * 100 for r_e in reconstruction_errors])
    return reconstruction_errors

# %%
def find_optimal_threshold(reconstruction_errors, y_true):
    from sklearn.metrics import accuracy_score, balanced_accuracy_score

    best_threshold = 0.0
    best_f1 = 0.0
    best_y_pred = np.zeros(reconstruction_errors.shape)
    # q3 = np.percentile(reconstruction_errors, 75)
    # q1 = np.percentile(reconstruction_errors, 25)
    # iqr = q3 - q1
    upper_bound = np.max(reconstruction_errors)
    lower_bound = np.min(reconstruction_errors)

    thresholds = np.linspace(lower_bound, upper_bound, num=500)

    for threshold in thresholds:
        y_pred = np.where((reconstruction_errors > threshold) ,1, 0)
        # print(y_pred.shape)
        # print(y_true.shape)

        # Hitung F1-Score
        current_f1 = balanced_accuracy_score(y_true.astype(bool), y_pred.astype(bool))

        if current_f1 > best_f1:
            best_f1 = current_f1
            best_threshold = threshold
            best_y_pred = y_pred

    return best_threshold, best_f1, best_y_pred

# %% [markdown]
# ## Training

# %%
merged_df = pd.read_csv("../../filtered_dataset/train/selected_instance_0.csv", index_col='timestamp')
merged_df = merged_df[160000:310000]

# %%
# merged_df = get_dataset('../../datasets/3W/dataset_processed/splitted/0/train')
merged_data_class = merged_df['class']
merged_data_np = merged_df.drop(['class'], axis=1).values

# %%
merged_data_np.shape
# Out:
# (150000, 4)

# %%
plt.figure(figsize=(15,7))
plt.plot(merged_data_np)
plt.legend(['T-TPT','P-TPT', 'P-MON-CKP', 'T-JUS-CKP'])
plt.title("Class 0 Train")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
import pickle

scaler = pickle.load(open('StandardScaler-3W-filtered-0.pkl', 'rb'))
merged_data_np_scaled = scaler.transform(merged_data_np)

# %%
merged_data_np_3d = convert_time_window(merged_data_np_scaled, 10)
# merged_data_np_3d = convert_time_window(merged_data_np, 10)

# %%
merged_data_np_3d.dtype
# Out:
# dtype('float32')

# %%
merged_data_np_3d.shape
# Out:
# (149991, 10, 4)

# %%
tf_dataset_path = "../../datasets/3W/dataset_processed/tf_data/LSTM-GAN/train-filtered-2/0_160k-310k"

dataset = tf.data.Dataset.from_tensor_slices(merged_data_np_3d)
dataset = dataset.batch(64)
tf.data.Dataset.save(dataset, tf_dataset_path)
# Out:
# 2024-10-13 18:04:15.587735: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.588038: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.588068: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.789534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.789730: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.789746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-10-13 18:04:15.789914: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:04:15.789952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2256 MB memory:  -> device: 0, name: NVIDIA T500, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# To use available dataset
tf_dataset_path = "../../datasets/3W/dataset_processed/tf_data/LSTM-GAN/train-filtered-2/0_160k-310k"
dataset = tf.data.Dataset.load(tf_dataset_path)
# Out:
# 2024-10-13 18:08:00.270123: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.270315: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.270360: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.411314: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.411416: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.411429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-10-13 18:08:00.411505: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-13 18:08:00.411528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2256 MB memory:  -> device: 0, name: NVIDIA T500, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ## ==================================================

# %%
def build_encoder(input_shape):
    input_layer = layers.Input(shape=input_shape)
    encoder = layers.LSTM(64, return_sequences=True)(input_layer)
    encoder = layers.LSTM(64, return_sequences=True)(encoder)
    encoder = layers.LSTM(64, return_sequences=True)(encoder)
    encoder = layers.Flatten()(encoder)
    encoder = layers.Dense(32)(encoder)
    encoder = layers.BatchNormalization()(encoder)
    encoder = layers.ReLU()(encoder)
    encoder = layers.Dense(24)(encoder)
    encoder = layers.BatchNormalization()(encoder)
    encoder = layers.ReLU()(encoder)
    output_layer = layers.Dense(10, activation='relu')(encoder)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer, name="Encoder")    
    return model

def build_decoder(output_shape):
    input_layer = layers.Input(shape=(10,))
    decoder = layers.Dense(10)(input_layer)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.ReLU()(decoder)
    decoder = layers.Dense(24)(decoder)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.ReLU()(decoder)
    decoder = layers.Dense(32)(decoder)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.ReLU()(decoder)
    decoder = layers.RepeatVector(output_shape[0])(decoder)

    decoder = layers.LSTM(64, return_sequences=True)(decoder)
    decoder = layers.LSTM(64, return_sequences=True)(decoder)
    decoder = layers.LSTM(64, return_sequences=True)(decoder)

    output_layer = layers.TimeDistributed(layers.Dense(output_shape[1]))(decoder)
    model = keras.models.Model(inputs=input_layer, outputs=output_layer, name="Decoder")
    
    return model

def build_discriminator(input_shape):
    input_layer = layers.Input(shape=input_shape)
    encoder = layers.LSTM(64, return_sequences=True)(input_layer)
    encoder = layers.LSTM(64, return_sequences=True)(encoder)
    encoder = layers.LSTM(64, return_sequences=True)(encoder)
    encoder = layers.Flatten()(encoder)
    encoder = layers.Dense(32)(encoder)
    encoder = layers.BatchNormalization()(encoder)
    encoder = layers.ReLU()(encoder)
    encoder = layers.Dense(24)(encoder)
    encoder = layers.BatchNormalization()(encoder)
    encoder = layers.ReLU()(encoder)
    encoder = layers.Dense(10, activation='relu')(encoder)
    output_layer = layers.Dense(1, activation='sigmoid')(encoder)
    
    model = keras.models.Model(inputs=input_layer, outputs=output_layer, name="Discriminator")

    return model

# %%
class Generator(models.Model):
    def __init__(self, input_shape, output_shape):
        super(Generator, self).__init__()
        self.encoder = build_encoder(input_shape)
        self.decoder = build_decoder(output_shape)

    def call(self, x):
        z = self.encoder(x)
        reconstructed_x = self.decoder(z)
        return reconstructed_x

# %%
# L1 norm for lx
def reconstruction_loss_lx(x, generated_x):
    return tf.reduce_mean(tf.abs(x - generated_x))

# L2 norm for lz
def reconstruction_loss_lz(z_enc1, z_enc2):
    return tf.reduce_mean(tf.square(z_enc1 - z_enc2))

# Adversarial loss for generator
def adversarial_loss(disc_output_gen):
    return tf.keras.losses.BinaryCrossentropy()(tf.ones_like(disc_output_gen), disc_output_gen)

# Total Generator loss
def generator_loss(x, generated_x, z_enc1, z_enc2, disc_output_gen, w1, w2, w3):
    x = tf.cast(x, tf.float16)
    generated_x = tf.cast(generated_x, tf.float16)
    z_enc1 = tf.cast(z_enc1, tf.float16)
    z_enc2 = tf.cast(z_enc2, tf.float16)
    disc_output_gen = tf.cast(disc_output_gen, tf.float16)

    lx = reconstruction_loss_lx(x, generated_x)
    lz = reconstruction_loss_lz(z_enc1, z_enc2)
    ladv = adversarial_loss(disc_output_gen)
    return w1 * lx + w2 * lz + w3 * ladv

# Discriminator loss
def discriminator_loss(real_output, fake_output):
    real_loss = tf.keras.losses.BinaryCrossentropy()(tf.ones_like(real_output), real_output)
    fake_loss = tf.keras.losses.BinaryCrossentropy()(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

# %%
# Define the input shape
time_window = 10 
features = 4 
input_shape = (time_window, features)

# Define optimizers
gen_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5) # from 1e-4, 1e-5
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=5e-6) # from 1e-6, 1e-5, 5e-6

# %% [markdown]
# ## ================================

# %%
# Instantiate models
generator = Generator(input_shape, input_shape)
discriminator = build_discriminator(input_shape)
encoder2 = build_encoder(input_shape)

# Example of compiling the discriminator
# discriminator.compile(optimizer=disc_optimizer, loss='binary_crossentropy')
# generator.encoder.compile(optimizer=gen_optimizer, loss=generator_loss)
# Out:
# 2024-10-12 15:47:35.665580: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
generator.encoder.summary()
# Out:
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 4)]           0
#
#  lstm (LSTM)                 (None, 10, 64)            17664
#
#  lstm_1 (LSTM)               (None, 10, 64)            33024
#
#  lstm_2 (LSTM)               (None, 10, 64)            33024
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 32)                20512
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  re_lu (ReLU)                (None, 32)                0
#
#  dense_1 (Dense)             (None, 24)                792
#
#  batch_normalization_1 (Bat  (None, 24)                96
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 24)                0
#
#  dense_2 (Dense)             (None, 10)                250
#
# =================================================================
# Total params: 105490 (412.07 KB)
# Trainable params: 105378 (411.63 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %%
generator.decoder.summary()
# Out:
# Model: "Decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  dense_3 (Dense)             (None, 10)                110
#
#  batch_normalization_2 (Bat  (None, 10)                40
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 10)                0
#
#  dense_4 (Dense)             (None, 24)                264
#
#  batch_normalization_3 (Bat  (None, 24)                96
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 24)                0
#
#  dense_5 (Dense)             (None, 32)                800
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 32)                0
#
#  repeat_vector (RepeatVecto  (None, 10, 32)            0
#  r)
#
#  lstm_3 (LSTM)               (None, 10, 64)            24832
#
#  lstm_4 (LSTM)               (None, 10, 64)            33024
#
#  lstm_5 (LSTM)               (None, 10, 64)            33024
#
#  time_distributed (TimeDist  (None, 10, 4)             260
#  ributed)
#
# =================================================================
# Total params: 92578 (361.63 KB)
# Trainable params: 92446 (361.12 KB)
# Non-trainable params: 132 (528.00 Byte)
# _________________________________________________________________

# %%
encoder2.summary()
# Out:
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 10, 4)]           0
#
#  lstm_9 (LSTM)               (None, 10, 64)            17664
#
#  lstm_10 (LSTM)              (None, 10, 64)            33024
#
#  lstm_11 (LSTM)              (None, 10, 64)            33024
#
#  flatten_2 (Flatten)         (None, 640)               0
#
#  dense_11 (Dense)            (None, 32)                20512
#
#  batch_normalization_7 (Bat  (None, 32)                128
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 32)                0
#
#  dense_12 (Dense)            (None, 24)                792
#
#  batch_normalization_8 (Bat  (None, 24)                96
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 24)                0
#
#  dense_13 (Dense)            (None, 10)                250
#
# =================================================================
# Total params: 105490 (412.07 KB)
# Trainable params: 105378 (411.63 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "Discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 10, 4)]           0
#
#  lstm_6 (LSTM)               (None, 10, 64)            17664
#
#  lstm_7 (LSTM)               (None, 10, 64)            33024
#
#  lstm_8 (LSTM)               (None, 10, 64)            33024
#
#  flatten_1 (Flatten)         (None, 640)               0
#
#  dense_7 (Dense)             (None, 32)                20512
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 32)                0
#
#  dense_8 (Dense)             (None, 24)                792
#
#  batch_normalization_6 (Bat  (None, 24)                96
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 24)                0
#
#  dense_9 (Dense)             (None, 10)                250
#
#  dense_10 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 105501 (412.11 KB)
# Trainable params: 105389 (411.68 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## ===================================

# %%
# Use when retraining existing models
generator = Generator(input_shape, input_shape)
generator.encoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-encoder.h5")
generator.decoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-decoder.h5")

encoder2 = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/encoder2.h5")
discriminator = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/discriminator.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
generator.encoder.summary()
# Out:
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 4)]           0
#
#  lstm (LSTM)                 (None, 10, 64)            17664
#
#  lstm_1 (LSTM)               (None, 10, 64)            33024
#
#  lstm_2 (LSTM)               (None, 10, 64)            33024
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 32)                20512
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  re_lu (ReLU)                (None, 32)                0
#
#  dense_1 (Dense)             (None, 24)                792
#
#  batch_normalization_1 (Bat  (None, 24)                96
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 24)                0
#
#  dense_2 (Dense)             (None, 10)                250
#
# =================================================================
# Total params: 105490 (412.07 KB)
# Trainable params: 105378 (411.63 KB)
# Non-trainable params: 112 (448.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## ====================================

# %%
# Prefetch for performance optimization
data_loader = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

epochs = 20 
w1 = 0.4 # from 0.25, 0.3, 0.3, 0.4
w2 = 0.3 # from 0.25, 0.3, 0.3, 0.2
w3 = 0.3 # from 0.5, 0.4, 0.4, 0.4

# Use @tf.function to compile functions involving gradient operations
@tf.function
def train_discriminator(batch, generator, discriminator, disc_optimizer):
    with tf.GradientTape() as disc_tape:
        real_output = discriminator(tf.convert_to_tensor(batch))  # Discriminator evaluates real data
        generated_x = generator(tf.convert_to_tensor(batch))
        fake_output = discriminator(generated_x)  # Discriminator evaluates generated data
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    disc_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
    return disc_loss

@tf.function
def train_generator(batch, generator, encoder2, discriminator, gen_optimizer, w1, w2, w3):
    with tf.GradientTape() as gen_tape:
        generated_x = generator(tf.convert_to_tensor(batch))  # Generator produces data from noise
        fake_output_gen = discriminator(generated_x)  # Discriminator evaluates generated data
        
        # Since we're training the generator, we compare the generated data against real data
        z_enc1 = generator.encoder(tf.convert_to_tensor(batch))  # Encoder1 with real data
        z_enc2 = encoder2(generated_x)  # Encoder2 with generated data
        
        gen_loss = generator_loss(batch, generated_x, z_enc1, z_enc2, fake_output_gen, w1, w2, w3)
    
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gen_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    return gen_loss

discriminator.trainable = False
# Training loop
for epoch in range(epochs):
    gen_loss_total = 0
    disc_loss_total = 0
    num_batches = 0

    with tqdm(total=len(data_loader), desc=f'Epoch {epoch+1}/{epochs}', unit='batch') as pbar:
        for batch in data_loader:
            batch_size = np.array(batch).shape[0]  
            num_batches += 1

            # Train the discriminator and generator
            disc_loss = train_discriminator(batch, generator, discriminator, disc_optimizer)
            gen_loss = train_generator(batch, generator, encoder2, discriminator, gen_optimizer, w1, w2, w3)
            
            if np.isnan(gen_loss.numpy()) or np.isnan(disc_loss.numpy()):
                print(f"[{num_batches}]: GENERATOR LOSS AND DISCRIMINATOR LOSS BECOME NaN. End train process...")
                break
            
            gen_loss_total += gen_loss.numpy()
            disc_loss_total += disc_loss.numpy()

            pbar.set_postfix({'loss_g': gen_loss.numpy(), 'loss_d': disc_loss.numpy()})
            pbar.update(1)  # Increment the progress bar by one batch

        # if num_batches % 100 == 0:
        #     print(f'[{num_batches}]: \tloss_g: {gen_loss}, loss_d: {disc_loss}')
        #     generator.encoder.save(f"../../models/3W/LSTM-GAN/train-filtered/0_0-150k/generator-encoder_E{epoch+1}.h5")
        #     generator.decoder.save(f"../../models/3W/LSTM-GAN/train-filtered/0_0-150k/generator-decoder_E{epoch+1}.h5")
        #     encoder2.save(f"../../models/3W/LSTM-GAN/train-filtered/0_0-150k/encoder2_E{epoch+1}.h5")
        #     discriminator.save(f"../../models/3W/LSTM-GAN/train-filtered/0_0-150k/discriminator_E{epoch+1}.h5")

    avg_gen_loss = gen_loss_total / num_batches
    avg_disc_loss = disc_loss_total / num_batches

    print(f'Epoch {epoch+1}/{epochs}, Generator Loss: {avg_gen_loss}, Discriminator Loss: {avg_disc_loss}')
    
    if not np.isnan(gen_loss.numpy()) and not np.isnan(disc_loss.numpy()):
        print("Save models")
        generator.encoder.save("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/generator-encoder.h5")
        generator.decoder.save("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/generator-decoder.h5")
        encoder2.save("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/encoder2.h5")
        discriminator.save("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/discriminator.h5")
# Out:
# Epoch 1/20:   0%|          | 0/2344 [00:00<?, ?batch/s]
# 2024-10-13 18:10:57.104715: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-10-13 18:11:08.713114: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3cb6fb47d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-13 18:11:08.713172: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA T500, Compute Capability 7.5
# 2024-10-13 18:11:08.730683: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728817868.902940  244203 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1/20: 100%|██████████| 2344/2344 [03:59<00:00,  9.80batch/s, loss_g=0.221, loss_d=1.39]
# Epoch 1/20, Generator Loss: 0.2506848748633479, Discriminator Loss: 1.3837246654790416
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/20: 100%|██████████| 2344/2344 [03:42<00:00, 10.53batch/s, loss_g=0.216, loss_d=1.39]
# Epoch 2/20, Generator Loss: 0.22148595816446245, Discriminator Loss: 1.3858370397481494
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/20: 100%|██████████| 2344/2344 [03:45<00:00, 10.39batch/s, loss_g=0.213, loss_d=1.39]
# Epoch 3/20, Generator Loss: 0.21824916800541275, Discriminator Loss: 1.3861226355561624
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/20: 100%|██████████| 2344/2344 [03:51<00:00, 10.14batch/s, loss_g=0.211, loss_d=1.39]
# Epoch 4/20, Generator Loss: 0.21632015501679822, Discriminator Loss: 1.386274886924659
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/20: 100%|██████████| 2344/2344 [03:39<00:00, 10.69batch/s, loss_g=0.209, loss_d=1.39]
# Epoch 5/20, Generator Loss: 0.21444780265105057, Discriminator Loss: 1.3864053553383504
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/20: 100%|██████████| 2344/2344 [03:57<00:00,  9.89batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 6/20, Generator Loss: 0.21352441156276664, Discriminator Loss: 1.3864349733033685
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/20: 100%|██████████| 2344/2344 [04:00<00:00,  9.77batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 7/20, Generator Loss: 0.21290916468909982, Discriminator Loss: 1.3864443716640766
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/20: 100%|██████████| 2344/2344 [03:50<00:00, 10.16batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 8/20, Generator Loss: 0.212253974159423, Discriminator Loss: 1.38645017915008
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/20: 100%|██████████| 2344/2344 [03:49<00:00, 10.23batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 9/20, Generator Loss: 0.2119065112221363, Discriminator Loss: 1.3864486701150802
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/20: 100%|██████████| 2344/2344 [03:50<00:00, 10.15batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 10/20, Generator Loss: 0.21159086780743389, Discriminator Loss: 1.3864464193277393
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/20: 100%|██████████| 2344/2344 [03:43<00:00, 10.48batch/s, loss_g=0.208, loss_d=1.39]
# Epoch 11/20, Generator Loss: 0.21134547731575298, Discriminator Loss: 1.386447552629705
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/20: 100%|██████████| 2344/2344 [03:37<00:00, 10.75batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 12/20, Generator Loss: 0.21137531788275918, Discriminator Loss: 1.3864502665736163
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/20: 100%|██████████| 2344/2344 [03:41<00:00, 10.56batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 13/20, Generator Loss: 0.21111034614641105, Discriminator Loss: 1.3864421234195956
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/20: 100%|██████████| 2344/2344 [03:27<00:00, 11.28batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 14/20, Generator Loss: 0.21083834390998293, Discriminator Loss: 1.3864366412671352
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/20: 100%|██████████| 2344/2344 [03:27<00:00, 11.28batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 15/20, Generator Loss: 0.2104883291615561, Discriminator Loss: 1.3864322029079594
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/20: 100%|██████████| 2344/2344 [03:50<00:00, 10.17batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 16/20, Generator Loss: 0.21034563604882145, Discriminator Loss: 1.3864300125389784
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/20: 100%|██████████| 2344/2344 [03:25<00:00, 11.38batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 17/20, Generator Loss: 0.21026501964790423, Discriminator Loss: 1.3864267793429996
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 18/20: 100%|██████████| 2344/2344 [03:53<00:00, 10.04batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 18/20, Generator Loss: 0.21053228280650063, Discriminator Loss: 1.3864264685546173
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/20: 100%|██████████| 2344/2344 [03:45<00:00, 10.40batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 19/20, Generator Loss: 0.21031407691512904, Discriminator Loss: 1.3864289399605156
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 20/20: 100%|██████████| 2344/2344 [03:32<00:00, 11.03batch/s, loss_g=0.207, loss_d=1.39]
# Epoch 20/20, Generator Loss: 0.21028371557033917, Discriminator Loss: 1.386428761858582
# Save models
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# generator.encoder.save("../../models/3W/LSTM-GAN/generator-encoder-v1.h5")
# generator.decoder.save("../../models/3W/LSTM-GAN/generator-decoder-v1.h5")
# encoder2.save("../../models/3W/LSTM-GAN/encoder2-v1.h5")
# discriminator.save("../../models/3W/LSTM-GAN/discriminator-v1.h5")

# %%
ttt = [np.array(batch).shape for batch in data_loader]
print(len(ttt))
# Out:
# 4720

# %%
# Sample dataset and training example
# train_data = merged_data_np_3d
# train_dataset = tf.data.Dataset.from_tensor_slices(train_data).batch(32)

# %% [markdown]
# ## Find Global Threshold

# %%
data_dir = "../../filtered_dataset/train"
data_files = ["selected_instance_2.csv", "selected_instance_4.csv"]

generator_encoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-2/150k-300k/generator-encoder.h5")
generator_decoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-2/150k-300k/generator-decoder.h5")

for data_file in data_files:
    merged_df = pd.read_csv(os.path.join(data_dir, data_file), index_col='timestamp')
    merged_data_np = merged_df.drop('class', axis=1).values
    merged_data_np_3d = convert_time_window(merged_data_np, 10)

    # FIND GLOBAL THRESHOLD
    dataset = tf.data.Dataset.from_tensor_slices(merged_data_np_3d)
    dataset = dataset.batch(64)

    results_list = []

    data_loader = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    for batch in data_loader:
        Z_train = generator_encoder(batch)
        train_3d_np = generator_decoder(Z_train).numpy()

        # train_2d_np = inverse_convert_time_window(train_3d_np)

        results_list.append(train_3d_np)

    final_results_3d_np = np.concatenate(results_list, axis=0)
    train_2d_np = inverse_convert_time_window(final_results_3d_np)

    r_e = calculate_reconstruction_loss(merged_data_np, train_2d_np)
    pd.DataFrame(r_e).to_csv(os.path.join("../../reconstruction_error/LSTM-GAN-2/", data_file), index=False)
# Out:
# 2024-10-06 10:28:46.802364: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2024-10-06 10:28:48.029242: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904

# %%
# merged_df = pd.read_csv("../../filtered_dataset/train/selected_instance_8.csv", index_col='timestamp')
# merged_data_np = merged_df.drop('class', axis=1).values
# merged_data_np_3d = convert_time_window(merged_data_np, 10)

# %%
# # FIND GLOBAL THRESHOLD
# dataset = tf.data.Dataset.from_tensor_slices(merged_data_np_3d)
# dataset = dataset.batch(64)

# results_list = []

# data_loader = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# for batch in data_loader:
#     Z_train = generator_encoder(batch)
#     train_3d_np = generator_decoder(Z_train).numpy()

#     # train_2d_np = inverse_convert_time_window(train_3d_np)

#     results_list.append(train_3d_np)

# final_results_3d_np = np.concatenate(results_list, axis=0)
# train_2d_np = inverse_convert_time_window(final_results_3d_np)

# %%
merged_df = pd.read_csv("../../filtered_dataset/train/selected_instance_0.csv", index_col='timestamp')
merged_df = merged_df[160000:310000]
merged_data_np = merged_df.drop('class', axis=1).values

scaler = pickle.load(open('StandardScaler-3W-0-filtered.pkl', 'rb'))
merged_data_np_scaled = scaler.transform(merged_data_np)
merged_data_np_3d = convert_time_window(merged_data_np_scaled, 10)

generator_encoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/generator-encoder.h5")
generator_decoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/0_160k-310k/generator-decoder.h5")


# FIND GLOBAL THRESHOLD
dataset = tf.data.Dataset.from_tensor_slices(merged_data_np_3d)
dataset = dataset.batch(64)

results_list = []

data_loader = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

for batch in data_loader:
    Z_train = generator_encoder(batch)
    train_3d_np = generator_decoder(Z_train).numpy()

    # train_2d_np = inverse_convert_time_window(train_3d_np)

    results_list.append(train_3d_np)

final_results_3d_np = np.concatenate(results_list, axis=0)
train_2d_np = inverse_convert_time_window(final_results_3d_np)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
r_e = calculate_reconstruction_loss(merged_data_np_scaled, train_2d_np)
pd.DataFrame(r_e).to_csv(os.path.join("../../reconstruction_error/LSTM-GAN-3/", "selected_instance_0_160k-310k.csv"), index=False)

# %%
plt.figure(figsize=(16,9))
plt.plot(merged_data_np_scaled, label=['real' for _ in range(merged_data_np_scaled.shape[1])])
plt.plot(train_2d_np, label=['reconstructed' for _ in range(train_2d_np.shape[1])])
plt.legend()
plt.title("Reconstruction")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.plot(r_e)
plt.title("Reconstruction error")
plt.show()

# %%
print(np.max(r_e))
# Out:
# 0.844367085352781

# %% [markdown]
# ## Testing

# %%
dataset_dir = "../../datasets/3W/dataset/2"
list_files = ["SIMULATED_00001.parquet","SIMULATED_00002.parquet","SIMULATED_00003.parquet"]

merged_df_test = pd.DataFrame(columns=['T-TPT','P-TPT', 'P-MON-CKP', 'T-JUS-CKP', 'class'])
for files in list_files:
    df = pd.read_parquet(os.path.join(dataset_dir, files))
    df = df[['T-TPT','P-TPT', 'P-MON-CKP', 'T-JUS-CKP', 'class']]
    merged_df_test = pd.concat([merged_df_test, df])
# merged_df_test = pd.read_parquet(dataset_dir)
# merged_df_test = merged_df_test[['T-TPT','P-TPT', 'P-MON-CKP', 'T-JUS-CKP', 'P-PDG', 'class']]

# Scale pressure columns (those starting with 'P') by 10^6
pressure_columns = [col for col in merged_df_test.columns if col.startswith('P')]
merged_df_test[pressure_columns] = merged_df_test[pressure_columns] / 10**6   

# dataset_dir = "../../datasets/3W/dataset_processed/splitted/2/test"

# list_files = os.listdir(dataset_dir)
# file_count = 4

# merged_df_test = pd.DataFrame(columns=['C1','C2','C3','class'])

# for i in range(file_count):
#     df = pd.read_csv(os.path.join(dataset_dir, list_files[i]), index_col='timestamp')
#     df.columns = ['C1','C2','C3','class']
#     merged_df_test = pd.concat([merged_df_test, df], ignore_index=True)

# %%
merged_data_test_class = merged_df_test['class']

merged_data_test_np = merged_df_test.drop('class', axis=1).values

# %%
scaler_test = pickle.load(open('StandardScaler-3W-2-filtered.pkl', 'rb'))
merged_data_test_np_scaled = scaler_test.transform(merged_data_test_np)
merged_data_test_np_3d = convert_time_window(merged_data_test_np_scaled, 10)

# %%
merged_data_test_np_3d.shape
# Out:
# (86388, 10, 4)

# %%
generator_encoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-encoder.h5")
generator_decoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-decoder.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
with tf.device('/CPU:0'):
    Z_test = generator_encoder(merged_data_test_np_3d)
# pred_3d_np = generator_decoder(Z_test).numpy()

# %%
with tf.device('/CPU:0'):
    pred_3d_np = generator_decoder(Z_test)

# %%
pred_2d = inverse_convert_time_window(pred_3d_np.numpy())
# pred_2d_inv = scaler_test.inverse_transform(pred_2d)

# %%
plt.figure(figsize=(13,7))
plt.plot(merged_data_test_np_scaled)
plt.plot(pred_2d)
# plt.legend(['C1','C2','C3','C1-rec','C2-rec','C3-rec',])
plt.show()

# %%
r_e = calculate_reconstruction_loss(merged_data_test_np_scaled, pred_2d)

# %%
thres, f1, y_pred = find_optimal_threshold((r_e), np.array(merged_data_test_class))
print(thres, f1)
# Out:
# 1.4064108091338339 0.9972750241411696

# %%
high_thres = 6.395205856593323
thres = 4.53448285788645
low_thres = 0.504167971928583

if min(r_e) > high_thres:
    y_pred = np.where((r_e > (thres + min(r_e))) ,1, 0)
else:
    y_pred = np.where((r_e > thres) ,1, 0)

# %%
thres = 1.333
y_pred = np.where((r_e > thres) ,1, 0)

# %%
# q3 = np.percentile(r_e, 75)
# q1 = np.percentile(r_e, 25)
# iqr = q3 - q1

plt.figure(figsize=(16,9))
plt.plot(r_e)
plt.plot(np.full(r_e.shape[0], thres), label='threshold')
# xmin, xmax, ymin, ymax = plt.axis()
# plt.fill_betweenx(np.linspace(thres-iqr, thres+iqr, 100), r_e.shape[0], color='blue', alpha=0.3)
plt.title("Reconstruction error")
plt.legend()
plt.show()

# %%
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(np.array(merged_data_test_class).astype(bool), y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'anomaly'])
cm_display.plot()

# %%
print("Accuracy: ", metrics.accuracy_score(np.array(merged_data_test_class).astype(bool), y_pred))
print("F1-score: ", metrics.f1_score(np.array(merged_data_test_class).astype(bool), y_pred))
# Out:
# Accuracy:  0.9938886766901629
# F1-score:  0.9964955597148659

# %%
plt.figure(figsize=(20,10))
plt.plot(merged_data_test_np)
plt.plot(pred_2d)
xmin, xmax, ymin, ymax = plt.axis()
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin, where=((~merged_data_test_class.astype(bool)) & (~y_pred)), color='green', alpha=0.3, label='normal')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=((merged_data_test_class.astype(bool)) & (y_pred)), color='red', alpha=0.3, label='anomaly')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=(~merged_data_test_class.astype(bool) & y_pred ), color='yellow', alpha=0.3, label='misclassified (FP)')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=(merged_data_test_class.astype(bool) & ~y_pred ), color='gray', alpha=0.3, label='misclassified (FN)')
# plt.legend(['P-PDG','P-TPT', 'T-TPT','P-PDG_rec','P-TPT_rec', 'T-TPT_rec','normal','anomaly','missclasiffied (FP)','missclasiffied (FN)'])
plt.legend()
plt.title("Class 2 Test: LSTM-GAN")
plt.show()

# %% [markdown]
# ## Smaller sample size testing

# %%
sample_test = pd.read_parquet("../../datasets/3W/dataset/1/SIMULATED_00095.parquet")
sample_test = sample_test[['T-TPT','P-TPT', 'P-MON-CKP', 'T-JUS-CKP', 'class']]

# Scale pressure columns (those starting with 'P') by 10^6
pressure_columns = [col for col in sample_test.columns if col.startswith('P')]
sample_test[pressure_columns] = sample_test[pressure_columns] / 10**6   

# sample_test = pd.read_csv('../../datasets/3W/dataset_processed/csv/2/WELL-00011_20141006150121.csv', index_col='timestamp')
# sample_test.dropna(inplace=True)
sample_test['class'].fillna(value=0, inplace=True) 
sample_test_class = sample_test['class']
sample_test_np = sample_test.drop('class',axis=1).values

# %%
sample_test.plot(figsize=(13,7))
# Out:
# <Axes: xlabel='timestamp'>

# %%
scaler_test = pickle.load(open('./StandardScaler-3W-0-filtered.pkl', 'rb'))
sample_test_np_scaled = scaler_test.transform(sample_test_np)
sample_test_np_3d = convert_time_window(sample_test_np_scaled, 10)

# %%
generator_encoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-encoder.h5")
generator_decoder = tf.keras.models.load_model("../../models/3W/LSTM-GAN/train-filtered-3/2/generator-decoder.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
with tf.device('/CPU:0'):
    Z_test = generator_encoder(sample_test_np_3d)
    pred_3d_np = generator_decoder(Z_test).numpy()

# %%
pred_2d = inverse_convert_time_window(pred_3d_np)

# %%
plt.figure(figsize=(13,7))
plt.plot(pred_2d)
# plt.plot(sample_test_np_scaled)
plt.show()

# %%
sample_r_e = calculate_reconstruction_loss(sample_test_np_scaled, pred_2d)

# %%
thres, f1, sample_y_pred  = find_optimal_threshold(r_e, sample_test_class)
print(thres, f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 thres, f1, sample_y_pred  = find_optimal_threshold(r_e, sample_test_class)
#       2 print(thres, f1)
#
# Cell In[7], line 21, in find_optimal_threshold(reconstruction_errors, y_true)
#      16 y_pred = np.where((reconstruction_errors > threshold) ,1, 0)
#      17 # print(y_pred.shape)
#      18 # print(y_true.shape)
#      19
#      20 # Hitung F1-Score
# ---> 21 current_f1 = balanced_accuracy_score(y_true.astype(bool), y_pred.astype(bool))
#      23 if current_f1 > best_f1:
#      24     best_f1 = current_f1
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2395, in balanced_accuracy_score(y_true, y_pred, sample_weight, adjusted)
#    2317 @validate_params(
#    2318     {
#    2319         "y_true": ["array-like"],
#    (...)
#    2325 )
#    2326 def balanced_accuracy_score(y_true, y_pred, *, sample_weight=None, adjusted=False):
#    2327     """Compute the balanced accuracy.
#    2328
#    2329     The balanced accuracy in binary and multiclass classification problems to
#    (...)
#    2393     0.625
#    2394     """
# -> 2395     C = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
#    2396     with np.errstate(divide="ignore", invalid="ignore"):
#    2397         per_class = np.diag(C) / C.sum(axis=1)
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/metrics/_classification.py:326, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     231 @validate_params(
#     232     {
#     233         "y_true": ["array-like"],
#    (...)
#     242     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     243 ):
#     244     """Compute confusion matrix to evaluate the accuracy of a classification.
#     245
#     246     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     324     (0, 2, 1, 1)
#     325     """
# --> 326     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     327     if y_type not in ("binary", "multiclass"):
#     328         raise ValueError("%s is not supported" % y_type)
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/metrics/_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/miniconda3/envs/tensor_gpu/lib/python3.9/site-packages/sklearn/utils/validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [74399, 86397]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# high_thres = 6.395205856593323
# thres = 4.53448285788645
# low_thres = 0.504167971928583
thres = 1.3333

if np.min(sample_r_e[1:]) > thres:
    sample_y_pred = np.where((sample_r_e > (thres + np.min(sample_r_e[1:]))) ,1, 0)
else:
    sample_y_pred = np.where((sample_r_e > thres) ,1, 0)

# %%
# q3 = np.percentile(sample_r_e, 75)
# q1 = np.percentile(sample_r_e, 25)
# iqr = q3 - q1

plt.figure(figsize=(16,9))
plt.plot(sample_r_e)
# plt.plot(np.full(sample_r_e.shape[0], thres + np.min(sample_r_e[1:])), label='threshold')
# xmin, xmax, ymin, ymax = plt.axis()
# plt.fill_betweenx(np.linspace(thres-iqr, thres+iqr, 100), sample_r_e.shape[0], color='blue', alpha=0.3)
plt.title("Reconstruction error")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20,10))
plt.plot(sample_test_np)
plt.plot(pred_2d)
xmin, xmax, ymin, ymax = plt.axis()
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin, where=((~sample_test_class.astype(bool)) & (~sample_y_pred)), color='green', alpha=0.3, label='normal')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=((sample_test_class.astype(bool)) & (sample_y_pred)), color='red', alpha=0.3, label='anomaly')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=(~sample_test_class.astype(bool) & sample_y_pred ), color='yellow', alpha=0.3, label='misclassified (FP)')
plt.fill_between(np.arange(0,len(pred_2d)), ymax, ymin,where=(sample_test_class.astype(bool) & ~sample_y_pred ), color='gray', alpha=0.3, label='misclassified (FN)')
# plt.legend(['P-PDG','P-TPT', 'T-TPT','P-PDG_rec','P-TPT_rec', 'T-TPT_rec','normal','anomaly','missclasiffied [FP]','missclasiffied [FN]'])
plt.legend()
plt.title("Class 1 Test: LSTM-Autoencoder")
plt.show()

# %%
print("Accuracy: ", metrics.accuracy_score(np.array(sample_test_class).astype(bool), sample_y_pred))
print("F1-score: ", metrics.f1_score(np.array(sample_test_class).astype(bool), sample_y_pred))
# Out:
# Accuracy:  0.5814863102998696
# F1-score:  0.7353443659637402

# %%
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(np.array(sample_test_class).astype(bool), sample_y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'anomaly'])
cm_display.plot()

# %%
gener = keras.models.load_model("generator_lstm_gan_10.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
merged_df_test = get_dataset('dataset_processed/splitted/2/test')
merged_data_test_class = merged_df_test['class']

merged_data_test_np = merged_df_test.drop('class', axis=1).values

# %%
scaler_test = pickle.load(open('StandardScaler.pkl', 'rb'))
merged_data_test_np_scaled = scaler_test.transform(merged_data_test_np)
merged_data_test_np_3d = convert_time_window(merged_data_test_np, 10)

# %%
test_data = merged_data_test_np_3d
fake_data = gener.predict(test_data)
# Out:
# 3439/3439 [==============================] - 15s 4ms/step

# %%
fake_data_2d = inverse_convert_time_window(fake_data)

# %%
scalerrr = sklearn.preprocessing.StandardScaler()
fake_data_2d_scaled = scalerrr.fit_transform(fake_data_2d)

# %%
plt.figure(figsize=(13,7))
plt.plot(merged_data_test_np_scaled)
plt.plot(fake_data_2d_scaled)
plt.show()

# %%
r_e = calculate_reconstruction_loss(merged_data_test_np_scaled, fake_data_2d_scaled)

plt.figure(figsize=(13,7))
plt.plot(r_e)
# plt.plot(fake_data_2d_scaled)
plt.show()

# %%
# Latent space reconstruction loss
latent_real = generator(test_data)
latent_fake = generator(fake_data)

anomaly_score = np.mean(np.square(latent_real - latent_fake), axis=1)

# %%
# Evaluate the model (replace `true_labels` with actual labels)
true_labels = np.random.randint(0, 4, size=1000)
evaluate_model(train_data, true_labels, thresholds=[0.2, 0.5, 0.7])
